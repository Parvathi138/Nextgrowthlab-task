# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a00620a8-ec2a-4b8a-b607-88d741b54b9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a00620a8-ec2a-4b8a-b607-88d741b54b9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving review_data.csv to review_data.csv

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['review_data.csv']))
print(df)
# Out:
#                                                     text  star  \
# 0                                        Anathi Khanyile     5
# 1      Tony bahut funny hai Hill climbing racing my f...     5
# 2                                                Teturwu     1
# 3      Hoooooooooooyaaaaaaaaa what a game hoooooooooo...     5
# 4                                      This game is nice     5
# ...                                                  ...   ...
# 29995                                 Plz my Vidos viral     5
# 29996                                               Nice     5
# 29997                  Disturbing too much as YouTube ad     1
# 29998                                      Koub valo vai     5
# 29999                          I want to grow my account     5
#
#                          app_id reviewDate
# 0      com.fingersoft.hillclimb   18/03/21
# 1      com.fingersoft.hillclimb   18/03/21
# 2      com.fingersoft.hillclimb   18/03/21
# 3      com.fingersoft.hillclimb   18/03/21
# 4      com.fingersoft.hillclimb   18/03/21
# ...                         ...        ...
# 29995                video.like   21/03/21
# 29996                video.like   21/03/21
# 29997                video.like   21/03/21
# 29998                video.like   21/03/21
# 29999                video.like   21/03/21
#
# [30000 rows x 4 columns]

# %%
#df = pd.read_csv('C:\\Users\\Chakrapani\\Documents\\Next_ASO\\review_data.csv')
#df = pd.read_csv('review_data.csv')
df.head()
# Out:
#                                                 text  star  \
# 0                                    Anathi Khanyile     5
# 1  Tony bahut funny hai Hill climbing racing my f...     5
# 2                                            Teturwu     1
# 3  Hoooooooooooyaaaaaaaaa what a game hoooooooooo...     5
# 4                                  This game is nice     5
#
#                      app_id reviewDate
# 0  com.fingersoft.hillclimb   18/03/21
# 1  com.fingersoft.hillclimb   18/03/21
# 2  com.fingersoft.hillclimb   18/03/21
# 3  com.fingersoft.hillclimb   18/03/21
# 4  com.fingersoft.hillclimb   18/03/21

# %%
cols = ['star', 'app_id','reviewDate']
df.drop(cols, axis=1, inplace=True)
df.head()
# Out:
#                                                 text
# 0                                    Anathi Khanyile
# 1  Tony bahut funny hai Hill climbing racing my f...
# 2                                            Teturwu
# 3  Hoooooooooooyaaaaaaaaa what a game hoooooooooo...
# 4                                  This game is nice

# %%
pip install language_tool_python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: language_tool_python in /usr/local/lib/python3.7/dist-packages (2.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from language_tool_python) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from language_tool_python) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->language_tool_python) (2.10)

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')

# %%
#text = """LanguageTool offers spell and grammar checking. Just paste your text here and click the 'Check Text' button. Click the colored phrases for details on potential errors. or use this text too see an few of of the problems that LanguageTool can detecd. What do you thinks of grammar checkers? Please not that they are not perfect. Style issues get a blue marker: It's 5 P.M. in the afternoon. The weather was nice on Thursday, 27 June 2017"""
for i in df.index:
    text = df['text'][i]
    matches = tool.check(text)
    count = len(matches)
    if count == 0:
        print(text," -- No mistakes")
    else:
        print(text," -- Mistakes found, ",count," mistakes")

tool.close()
# Out:
# Anathi Khanyile  -- Mistakes found,  2  mistakes
# Tony bahut funny hai Hill climbing racing my favourite game  -- Mistakes found,  3  mistakes
# Teturwu  -- Mistakes found,  1  mistakes
# Hoooooooooooyaaaaaaaaa what a game hooooooooooooyaaaaaaaa  -- Mistakes found,  2  mistakes
# This game is nice  -- No mistakes
# Rahulyadavo  -- Mistakes found,  1  mistakes
# First thing is that I like this game, it's fantastic and amazing. Though I rate it 4 stars cuz it's right pedal stops working in the game and that's why I kept falling on the bridge.  -- Mistakes found,  1  mistakes
# Very taty  -- Mistakes found,  1  mistakes
# good  -- No mistakes
# I LIKE THIS GAME  -- No mistakes
# Racing  -- No mistakes
# 😆😆😆  -- No mistakes
# Awesome game. easy to use options.  -- Mistakes found,  1  mistakes
# Very noob game  -- No mistakes
# Hill climb racing 2 vip game  -- Mistakes found,  1  mistakes
# Good games  -- No mistakes
# I is so oosem game  -- Mistakes found,  2  mistakes
# Good game  -- No mistakes
# All right for the price you pay.  -- No mistakes
# I like the app, it works really well. It is a much better experience then the website.  -- No mistakes
# Chicago  -- No mistakes
# Please add dark amoled theme  -- Mistakes found,  1  mistakes
# Very easy to use and my delivery was quick and very well protected. Thank you! A+  -- Mistakes found,  1  mistakes
# Awesome  -- No mistakes
# Excelent Best of all  -- Mistakes found,  1  mistakes
# I've been ordering here for years. Updated to say its still pretty good in 2021  -- Mistakes found,  1  mistakes
# Why is Alixpress customer service not Available. Like I don't understand please Please reply me  -- Mistakes found,  2  mistakes
# Very useful app 👌  -- No mistakes
# Excellent products and speed of shipments.  -- No mistakes
# Fast, simple to use. Best shipping I know of. Everything you can imagine on electronics is there and there are quite a few amazing, unknown to the US items --- really worth it. This is the ONLY app from which in never mind getting ads! 😂  -- No mistakes
# 👍  -- No mistakes
# Love the possibilities of the app. Working wel.  -- Mistakes found,  1  mistakes
# Great  -- No mistakes
# I Love AliExpress and All Sellers in AliExpress No Scam Zone ★★★★★  -- No mistakes
# I have ordered severally using the app and its very reliable shipping is fast anf what you order is what you get  -- Mistakes found,  1  mistakes
# The search engine needs work. Doesn't work as well as I'd like. A lot of useless items come up in a search that has none of the words I searched for in the title.  -- No mistakes
# Great  -- No mistakes
# Good but late  -- No mistakes
# This app is great for finding stuff at somewhat reasonable prices. But just like wish they start to progressively stop sending your products within the scheduled time or don't send them at all. Once a dispute is brought up the seller's want to lie about ETAs. I done with this app. Since Covid-19 they have making any excuse to not send your items. Tracking numbers do not track the package. Genuinely done with this app after my previous orders arrive or if they ever do.  -- Mistakes found,  2  mistakes
# Very reasonable shipping times to the USA. If you own a computer business as I do, AliExpress is a must.  -- No mistakes
# Fun fun fun  -- No mistakes
# Very good app  -- No mistakes
# Is incredible...  -- No mistakes
# Very good  -- No mistakes
# Great honest app..  -- Mistakes found,  1  mistakes
# App itself is good, easy to use and with loads of inexpensive items to buy, but gets 2 stars. The app is just one part of it. The other part is the service and delivery of things you have bought. Unfortunately this side of AliExpress is very poor. 2 months of waiting for purchases to arrive so far... if you want an item quick forget this and go to a local shop. You do have different freight options but these are pricey and so nullify any savings you may make.  -- Mistakes found,  1  mistakes
# I can't live without Ali Express ido alot of shopping 🛒  -- Mistakes found,  3  mistakes
# 👍  -- No mistakes
# Would have given 5 stars if Cash on delivery option was available..  -- Mistakes found,  1  mistakes
# Nice app  -- No mistakes
# Produtos variados e com ótimo preço. Mas o tempo de espera para chegar o produto na sua casa... Vish!  -- Mistakes found,  11  mistakes
# So far so good,got items on time  -- Mistakes found,  1  mistakes
# Amazing app. Best place to purchase your product internationally  -- No mistakes
# Ali express is great. Sometimes orders take a very long time but I'm ok with it as long as my things arrive when it says .  -- Mistakes found,  3  mistakes
# Love this app. Some things take awhile to receive, that is clearly stated on items that are ordered.  -- Mistakes found,  1  mistakes
# Fast delivery  -- No mistakes
# Some shipments take long, and most of the things they sell is cheap but i really like this app because the stuff is cheap depending on what you order :)  -- Mistakes found,  1  mistakes
# رائع للتسوق  -- No mistakes
# YOU NOOB NO LEGO POLICE BOAY 60045 👎😭😢😡  -- Mistakes found,  1  mistakes
# Too many problems with service. I am done. Not an easy solution and prices are about same as Amazon for same prices..and better problem resolution  -- Mistakes found,  1  mistakes
# This App Really Makes Shopping Easy and Fun  -- No mistakes
# Excellent  -- No mistakes
# Am very happy to use this app everything is straight forward and deliveries are quick  -- No mistakes
# got credit card fraud the next day after my first purchase. But yea what do I expect on a cheap website.  -- Mistakes found,  1  mistakes
# Very nice app  -- No mistakes
# Very easy app to use. Lots to choose from.  -- No mistakes
# Theres one item that i didnt get, but i still like this better than others apps.  -- Mistakes found,  3  mistakes
# With time I will give it 5 stars Started using it not quite long  -- Mistakes found,  1  mistakes
# All I can say is I LOVE LOVE LOVE ALIEXPRESS, the prices are great and if you shop around you can find the same item sold by different sellers, some cheaper, with free shipping and some are better quality than others - ALWAYS CHECK OUT REVIEWS THEY HELP SO MUCH!!! - Well worth the wait for shipping. Vendors are great and if there is a problem (which doesn't happen much), AliExpress works with purchasers and refunds cost including shipping if appropriate.  -- Mistakes found,  1  mistakes
# Amazing  -- No mistakes
# For the years I've been on AliExpress I've ONLY had a handful of negative experiences. The overall experience has been positive. Let's hope they keep it going in a great direction  -- No mistakes
# I liked spending time on this app as it has a variety of products to offer...you can buy anything of your choice and interest sitting at home.. different sales days and promotions also make it more attractive for someone who loves to shop economically...but can you please provide us the facility of cash on delivery. ?  -- Mistakes found,  2  mistakes
# Good  -- No mistakes
# Nice  -- No mistakes
# My favourite app  -- Mistakes found,  1  mistakes
# Great service.  -- No mistakes
# Good deals but too long shipping time could it be Faster ??  -- No mistakes
# Awesome  -- No mistakes
# I'm very satisfied with their service. This is the best online shopping app I have used so far. Highly recommend  -- No mistakes
# Was enjoying the app initially but now its a total mess, you order something, the seller sends incomplete items and you can neither open dispute, send the seller a message nor contact the support team. You just end up losing your money!This is very irresponsible of Ali express in short thus is cheating!  -- Mistakes found,  3  mistakes
# The delivery is extremely poor! very poor indeed.Even if an order is delivered by foot from overseas, it cant surely take over 4 months.Other online business platforms like kilmall are exemplary. Ali Express you need to have a total turnaround.  -- Mistakes found,  6  mistakes
# Package was in perfect condition. Shipping was faster than expected..  -- Mistakes found,  1  mistakes
# New customer. Little bit wary at first but no real worries as my few items are small and low value. So far the first one arrived today. I ordered it 5 weeks ago but the tracking info on the app is pretty informative. Waiting on the others...  -- Mistakes found,  2  mistakes
# 👍👍  -- No mistakes
# Fair and good  -- No mistakes
# Amazing  -- No mistakes
# So reliable.  -- No mistakes
# Very nice  -- No mistakes
# Worst customer support. Bloody robot dont let you chat with agent and doesn't answer to queries. Disputes are pending from three months but Aliexpress is sleeping  -- Mistakes found,  2  mistakes
# Awesome and user friendly  -- Mistakes found,  1  mistakes
# Useless.. fake  -- Mistakes found,  2  mistakes
# Super  -- No mistakes
# Love it  -- No mistakes
# Great  -- No mistakes
# Excellent  -- No mistakes
# They have really good stuff, I've just had a lot of problems with shipping :( It usually takes 2-3 months to get something delivered.  -- Mistakes found,  2  mistakes
# Amazing selection  -- No mistakes
# Totally satisfied with shipping time and product's in which I have purchased.  -- No mistakes
# Very good  -- No mistakes
# Very good Shopping Apps  -- No mistakes
# Is ok  -- No mistakes
# 🙃🙂  -- No mistakes
# 😊  -- No mistakes
# Good app you can get anything you want at any store at your convenience time  -- No mistakes
# Best app  -- No mistakes
# Very bad experience buying in this platform. Delivery is often more than 30 days and up to 55 days. Dispute is handled by robot and no real people behind it. Return shipping for faulty item is paid by the buyer and most of the time is expensive and not worth it. The price published for a product is often based on the lowest forex rate so that the item look cheaper. So many manipulations inside this platform. I would advise anyone not to buy from this platform.There are better platforms out there  -- Mistakes found,  1  mistakes
# I just had an amazing experience with AliExpress  -- No mistakes
# Very good site easy to use  -- No mistakes
# Yep really good until use it a few more times. Thanks. Tony,  -- Mistakes found,  1  mistakes
# Trusted and reliable Fast and cheap Accurate and sure  -- No mistakes
# Very useful  -- No mistakes
# The app is convenient but, items are too small to see correctly. This makes it hard to choose the right colors. The app is a little difficult. I also encountered a clip of porn in one of the product streams. I like using the computer better than the app.  -- No mistakes
# I love how they have so many products!  -- No mistakes
# Good  -- No mistakes
# Easy to look for anything needed  -- No mistakes
# nice  -- No mistakes
# Its good  -- Mistakes found,  1  mistakes
# Excellent  -- No mistakes
# It's simply the best  -- No mistakes
# Yeah, it's alright  -- No mistakes
# I am using yahoo more than 15 years and happy to use it in the future. Thank yahoo.  -- No mistakes
# Convenient  -- No mistakes
# Works for me.  -- No mistakes
# Very good 👍  -- No mistakes
# Easy to work and read  -- No mistakes
# Great!  -- No mistakes
# I order all the time from Affirm their pretty reasonable and their fair  -- Mistakes found,  1  mistakes
# Great!  -- No mistakes
# Very effective and quick  -- No mistakes
# This is absolutely the worst email app out there. I'm very disappointed I actually thought that Yahoo after all these years would have had their act together when it came to providing good reliable and fast and accurate email. Just to give you a for instance when I try to delete an email, I can't get rid of it, and it takes two or three tries before it's finally deleted. This email app by Yahoo has a lot of glitches and bugs in it. The bottom line is I don't recommend that you install this.  -- No mistakes
# It's email...  -- No mistakes
# I can't open links on my email I have updated and reinstall it and still having trouble trying to open a link on a email li yes I do have Tmobile but I never had problems with it  -- Mistakes found,  4  mistakes
# Its working satisfactory.  -- No mistakes
# Very satisfied  -- No mistakes
# Serves my needs very well.  -- No mistakes
# Good experience  -- No mistakes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ab1be50c744a> in <module>()
#       2 for i in df.index:
#       3     text = df['text'][i]
# ----> 4     matches = tool.check(text)
#       5     count = len(matches)
#       6     if count == 0:
#
# /usr/local/lib/python3.7/dist-packages/language_tool_python/server.py in check(self, text)
#     127         """Match text against enabled rules."""
#     128         url = urllib.parse.urljoin(self._url, 'check')
# --> 129         response = self._query_server(url, self._create_params(text))
#     130         matches = response['matches']
#     131         return [Match(match) for match in matches]
#
# /usr/local/lib/python3.7/dist-packages/language_tool_python/server.py in _query_server(self, url, params, num_tries)
#     216         for n in range(num_tries):
#     217             try:
# --> 218                 with requests.get(url, params=params, timeout=self._TIMEOUT) as response:
#     219                     try:
#     220                         return response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59     # cases, and look like a memory leak in others.
# ---> 60     with sessions.Session() as session:
#      61         return session.request(method=method, url=url, **kwargs)
#      62
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in __init__(self)
#     412         # Default connection adapters.
#     413         self.adapters = OrderedDict()
# --> 414         self.mount('https://', HTTPAdapter())
#     415         self.mount('http://', HTTPAdapter())
#     416
#
# KeyboardInterrupt:
